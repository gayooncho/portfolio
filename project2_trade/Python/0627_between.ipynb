# %%
import numpy as np
import pandas as pd

# %%
hs6_bec = pd.read_csv('C:\project2\Python\hs6_bec.csv')

# 6자리 맞춰주기 / str로 바꾼뒤 앞에 0붙여줌
hs6_bec['HS'] = hs6_bec['HS'].astype('str')
hs6_bec['HS'] = hs6_bec['HS'].str.zfill(width=6)

# %%
# trade_between_China_and_United_States_of_America exported 파일 불러오기
trade_between_China_and_United_States_of_America_exported_list = pd.read_table('C:\project2\Trade_Map_Existing_and_potential_trade_between\Trade_Map_-_Existing_and_potential_trade_between_China_and_United_States_of_America.txt', sep = '\t')

# code -> hs로 컬럼 이름 변경
trade_between_China_and_United_States_of_America_exported_list.rename(columns={'Product code':'HS'}, inplace=True)
trade_between_China_and_United_States_of_America_exported_list.head()
# Out:
#        HS                                      Product label  \
# 0   TOTAL                                       All products
# 1  854231  Electronic integrated circuits as processors a...
# 2  854239  Electronic integrated circuits (excluding such...
# 3  854232         Electronic integrated circuits as memories
# 4  901380  Liquid crystal devices, n.e.s. and other optic...
#
#    China's imports from Taipei, Chinese-Value in 2012  \
# 0                                          132199339
# 1                                           26504559
# 2                                           11928420
# 3                                            9230983
# 4                                           15750888
#
#    China's imports from Taipei, Chinese-Value in 2013  \
# 0                                          156405132
# 1                                           33051409
# 2                                           19041313
# 3                                           12558951
# ...

# %%
#   1) code 열에 total 제거
# 제거
trade_between_China_and_United_States_of_America_exported_list = trade_between_China_and_United_States_of_America_exported_list.drop([trade_between_China_and_United_States_of_America_exported_list.index[0]])

#   2) United_States_of_America 데이터 프레임에 hs 코드 데이터 타입 형변환
# trade_between_China_and_United_States_of_America_exported_list['HS'] = pd.to_numeric(trade_between_China_and_United_States_of_America_exported_list['HS'])
trade_between_China_and_United_States_of_America_exported_list['HS'] = trade_between_China_and_United_States_of_America_exported_list['HS'].astype('str')


#   2) merge를 사용해 hs코드 기준으로 데이터 프레임 병합
trade_between_China_and_United_States_of_America_exported_list = pd.merge(trade_between_China_and_United_States_of_America_exported_list, hs6_bec, how='left', on='HS')

#   2-1) hs 코드 자리수 맞춰주기 -> 5자리인경우 앞에 0붙여주기
trade_between_China_and_United_States_of_America_exported_list['HS'] = trade_between_China_and_United_States_of_America_exported_list['HS'].astype('str')
#       HS코드 6자리로 맞춰주기, 없는경우 left에 0으로 붙여줌
# trade_between_China_and_United_States_of_America_exported_list['HS'].str.pad(width=6, side='left', fillchar='0')
trade_between_China_and_United_States_of_America_exported_list['HS'] = trade_between_China_and_United_States_of_America_exported_list['HS'].str.zfill(width=6)

#   2-2 hs코드 잘라서 hs4에 넣어주기
trade_between_China_and_United_States_of_America_exported_list['HS4'] = trade_between_China_and_United_States_of_America_exported_list['HS'].str.slice(0, 4)


trade_between_China_and_United_States_of_America_exported_list.head()
# Out:
#        HS                                      Product label  \
# 0  854231  Electronic integrated circuits as processors a...
# 1  854239  Electronic integrated circuits (excluding such...
# 2  854232         Electronic integrated circuits as memories
# 3  901380  Liquid crystal devices, n.e.s. and other optic...
# 4  847170  Storage units for automatic data-processing ma...
#
#    China's imports from Taipei, Chinese-Value in 2012  \
# 0                                           26504559
# 1                                           11928420
# 2                                            9230983
# 3                                           15750888
# 4                                             246729
#
#    China's imports from Taipei, Chinese-Value in 2013  \
# 0                                           33051409
# 1                                           19041313
# 2                                           12558951
# 3                                           15507797
# ...

# %%
no_exported_id = trade_between_China_and_United_States_of_America_exported_list[
                    (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from United States of America-Value in 2012'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from United States of America-Value in 2013'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from United States of America-Value in 2014'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from United States of America-Value in 2016'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from United States of America-Value in 2017'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from United States of America-Value in 2018'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from United States of America-Value in 2019'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from United States of America-Value in 2020'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from United States of America-Value in 2021'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['United States of America\'s exports to world- '] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['United States of America\'s exports to world-Value in 2012'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['United States of America\'s exports to world-Value in 2013'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['United States of America\'s exports to world-Value in 2014'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['United States of America\'s exports to world-Value in 2016'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['United States of America\'s exports to world-Value in 2017'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['United States of America\'s exports to world-Value in 2018'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['United States of America\'s exports to world-Value in 2019'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['United States of America\'s exports to world-Value in 2020'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['United States of America\'s exports to world-Value in 2021'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from world- '] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from world-Value in 2012'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from world-Value in 2013'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from world-Value in 2014'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from world-Value in 2016'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from world-Value in 2017'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from world-Value in 2018'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from world-Value in 2019'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from world-Value in 2020'] == 0)
                    & (trade_between_China_and_United_States_of_America_exported_list['China\'s imports from world-Value in 2021'] == 0)
                    
                    ].index

# # 거래품목 없는 인덱스 제거
# trade_between_China_and_United_States_of_America_exported_list = trade_between_China_and_United_States_of_America_exported_list.drop(no_exported_id)
# trade_between_China_and_United_States_of_America_exported_list.isnull().sum()

# %%
hs4_bec = hs6_bec[['HS4','BEC']]

# hs4, bec코드 정리
hs4_bec.dropna(axis=0, inplace= True)

hs4_bec['HS4'] = hs4_bec['HS4'].astype('int')
hs4_bec['BEC'] = hs4_bec['BEC'].astype('float')

#### HS4 코드로 BEC NaN값 채우기

# 순수한 hs4코드를 모은 데이터베이스 만들기

# hs4_bec에서 hs4코드만 추출
hs4 = hs4_bec['HS4']

# hs4와 bec 값이 중복되는 행 제거
hs4.drop_duplicates(inplace=True)

# hs4 데이터프레임으로 형변환
hs4 = hs4.to_frame()

# 인덱스 초기화
hs4.reset_index(inplace=True)

# hs4에 대하여 bec 코드가 없는 행
# bec 값에 0
hs4_bec.loc[3513,'HS4'] = 0
hs4_bec.loc[3542,'HS4'] = 0
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20740\1915619902.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec.dropna(axis=0, inplace= True)
# C:\Users\user\AppData\Local\Temp\ipykernel_20740\1915619902.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec['HS4'] = hs4_bec['HS4'].astype('int')
# C:\Users\user\AppData\Local\Temp\ipykernel_20740\1915619902.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# 사전가져오기
import pickle
# 사전 불러오기
with open('C:\project2\Python\hs4_bec.pkl', 'rb') as f:
    hs4_dict = pickle.load(f)

# %%
add_BEC = trade_between_China_and_United_States_of_America_exported_list[trade_between_China_and_United_States_of_America_exported_list['BEC'].isnull()]

# BEC 코드를 새로 부여하기 위해 기존 BEC 행 제거
add_BEC.drop(['BEC'], axis=1, inplace=True)

add_BEC.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20740\1751519577.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_BEC.drop(['BEC'], axis=1, inplace=True)
#           HS                                      Product label  \
# 96    999999                Commodities not elsewhere specified
# 4510  711890                               Coin of legal tender
# 5108  854800  Electrical parts of machinery or apparatus, n....
#
#       China's imports from Taipei, Chinese-Value in 2012  \
# 96                                                 6242
# 4510                                                  0
# 5108                                                  0
#
#       China's imports from Taipei, Chinese-Value in 2013  \
# 96                                                46697
# ...

# %%
# 행 늘리기 위한 hs4 count 
hs4_bec_over = hs4_bec.drop_duplicates()
hs4_count = hs4_bec_over.groupby('HS4').count()

# %%
add_BEC_index = (add_BEC.index).to_list()
hs4_count_index = (hs4_count.index).to_list()

### 행 늘리기 - how
# 1. 늘려야하는 행들 확인
# 2. n개로 행 늘려주기
# 문제!!! 마지막 행이 항상 오류뜸 복사 붙여넣기 해주면 작동함
for i in add_BEC_index:
    com_key = int(add_BEC.loc[i, 'HS4'])
    for j in hs4_count_index:
        count = int(hs4_count.loc[j])       # count개수만큼 행 추가
        hs4Temp = int(j)
        # print(hs4Temp)
        # print(count, hs4Temp, com_key)
        if (count > 1) & (com_key == hs4Temp):  # 추가해야할 행이 2개이상이고, com_key와 hs4Tmep이 같을 경우
            for m in range(count - 1):  # count 개수만큼 행 추가
            #     # add_BEC = pd.concat([add_BEC, add_BEC.loc[[i]]], ignore_index = True)
                add_BEC = pd.concat([add_BEC, add_BEC.loc[[i]]], ignore_index = True)

# %%
# 위에서 행을 늘려주었기 때문에 인덱스 에러
# 인덱스 초기화
add_BEC.reset_index(inplace=True)

# 금액 나누기
for i in range(len(add_BEC)):
    com_key = int(add_BEC.loc[i, 'HS4'])
    for j in hs4_count_index:
        count = int(hs4_count.loc[j])       # count개수만큼 행 추가
        hs4Temp = int(j)
        if (count > 1) & (com_key == hs4Temp):
            for m in range(count):      # count 개수만큼 금액 나누기            
                add_BEC.loc[i,'Exported value in 2012'] = (add_BEC.loc[i, 'Exported value in 2012'] / count)
                add_BEC.loc[i,'Exported value in 2013'] = (add_BEC.loc[i, 'Exported value in 2013'] / count)
                add_BEC.loc[i,'Exported value in 2014'] = (add_BEC.loc[i, 'Exported value in 2014'] / count)
                add_BEC.loc[i,'Exported value in 2015'] = (add_BEC.loc[i, 'Exported value in 2015'] / count)
                add_BEC.loc[i,'Exported value in 2016'] = (add_BEC.loc[i, 'Exported value in 2016'] / count)
                add_BEC.loc[i,'Exported value in 2017'] = (add_BEC.loc[i, 'Exported value in 2017'] / count)
                add_BEC.loc[i,'Exported value in 2018'] = (add_BEC.loc[i, 'Exported value in 2018'] / count)
                add_BEC.loc[i,'Exported value in 2019'] = (add_BEC.loc[i, 'Exported value in 2019'] / count)
                add_BEC.loc[i,'Exported value in 2020'] = (add_BEC.loc[i, 'Exported value in 2020'] / count)
                add_BEC.loc[i,'Exported value in 2021'] = (add_BEC.loc[i, 'Exported value in 2021'] / count)

# %%
# HS4 코드 기준으로 SORT 
# 새로운 데이터프레임 add_BEC_sort에 넣기
add_BEC_sort = add_BEC.sort_values('HS4')
# add_BEC_sort_index = (add_BEC_sort.index).to_list()
add_BEC_sort.drop(['index'], axis=1, inplace = True)
add_BEC_sort.reset_index(inplace = True)

# %%
# HS4코드 기준으로 dict에서 bec코드 각각 넣어주기
x = 0

for i in range(len(add_BEC_sort)):
    com_key = int(add_BEC_sort.loc[i, 'HS4'])
    for key, value in hs4_dict.items(): 
        # print( com_key,key, len(value))
        if (key == com_key):
            try:
                if len(value) == 1:
                    x = 0
                    # add_BEC_new.loc[i, 'HS4'] = key
                    add_BEC_sort.loc[i, 'BEC'] = value[x]
                    # print(add_BEC_sort.loc[i, 'BEC'])
                else:
                    add_BEC_sort.loc[i, 'BEC'] = value[x]
                    # print(i,key ,com_key, value[x], add_BEC_sort.loc[i, 'BEC'])
                    x = x + 1
                    if x == len(value):
                        x = 0
            except: IndexError

# %%
#### 원 데이터(bec 값 있는 것)와 add데이터 concat

#   1) ROW 데이터에서 BEC 코드 있는 데이터
trade_between_China_and_United_States_of_America_exported_list_bec = (trade_between_China_and_United_States_of_America_exported_list[trade_between_China_and_United_States_of_America_exported_list['BEC'].notnull()])

#   2) 모든 데이터들 넣어줄 데이터 프레임 생성
trade_between_China_and_United_States_of_America_exported = pd.DataFrame

#   3) add_BEC_sort와 trade_between_China_and_United_States_of_America_exported_list_bec concat
trade_between_China_and_United_States_of_America_exported = pd.concat([trade_between_China_and_United_States_of_America_exported_list_bec, add_BEC_sort])

# %%
trade_between_China_and_United_States_of_America_exported.to_csv('./finish/trade_between_China_and_United_States_of_America_exported.csv')
