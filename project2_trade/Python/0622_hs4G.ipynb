# %%
import numpy as np
import pandas as pd

# %%
# hs / bec 파일 불러오기, excel 파일의 두번째 sheet
hs_bec = pd.read_excel('C:\project2\BEC5Correlations\HS2012-17-BEC5 -- 08 Nov 2018.xlsx'
                       , sheet_name = "HS17BEC5")

# hs4, hs6, bec, bec processing, bec specitication 목록만 별도로 추출
hs_bec = hs_bec[['HS4','HS6','BEC5Code1', 'BEC5Processing', 'BEC5Specification']]

# hs code -> code 이름변경
hs_bec.rename(columns={'HS4':'HS4', 'HS6':'HS', 'BEC5Code1':'BEC', 
                       'BEC5Processing':'BEC_Pro', 'BEC5Specification':'BEC_Spec'}, inplace=True)

# %%
hs4_bec = hs_bec[['HS4','BEC']]

# %%
hs4_bec.head()
# Out:
#    HS4       BEC
# 0  101  712010.0
# 1  101    1111.0
# 2  101    1111.0
# 3  101    1111.0
# 4  102  112010.0

# %%
# hs4, bec코드 정리
hs4_bec['HS4'] = hs4_bec['HS4'].astype('int')


hs4_bec.dropna(axis=0, inplace= True)
# hs4_count = hs4_bec['HS4'].value_counts()
# hs4_count = pd.DataFrame(hs4_count)

# hs4_count.reset_index(inplace=True)
# hs4_count.columns = ['HS4', 'HS4_COUNT']

hs4_bec.groupby('HS4').count()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21904\816420516.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec['HS4'] = hs4_bec['HS4'].astype('int')
# C:\Users\user\AppData\Local\Temp\ipykernel_21904\816420516.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec.dropna(axis=0, inplace= True)
#       BEC
# HS4
# 101     4
# 102     5
# 103     3
# 104     2
# 105     7
# ...   ...
# 9702    1
# 9703    1
# 9704    1
# 9705    1
# 9706    1
#
# [1222 rows x 1 columns]

# %%
hs4_bec['HS4'] = hs4_bec['HS4'].astype('int')
hs4_bec['BEC'] = hs4_bec['BEC'].astype('float')

# hs_bec4.set_index('HS4').T.to_dict('list')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21904\1937868492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec['HS4'] = hs4_bec['HS4'].astype('int')
# C:\Users\user\AppData\Local\Temp\ipykernel_21904\1937868492.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec['BEC'] = hs4_bec['BEC'].astype('float')

# %%
hs4 = hs4_bec['HS4']

hs4.drop_duplicates(inplace=True)

hs4 = hs4.to_frame()

hs4.reset_index(inplace=True)
hs4.count()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21904\909227547.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4.drop_duplicates(inplace=True)
# index    1222
# HS4      1222
# dtype: int64

# %%
## 겹치지 않도록 hs4값과 bec 값 넣은 dict

# from collections import defaultdict
# hs4_dict = defaultdict(list)
    
# hs4_bec.loc[0, 'HS4']
# for i in range(len(hs4)) :
#     hs4Temp = hs4.loc[i, 'HS4']
#     for j in range(3512):
#         hsbecTemp = hs4_bec.loc[j, 'HS4']
#         if hs4Temp == hsbecTemp :
#             hs4_dict[hs4Temp].append(hs4_bec.loc[j, 'BEC'])
#         pass

# hs4_dict

# %%
# hs4_dict[7104]

# %%
from collections import defaultdict
hs4_dict = defaultdict(list)
    
hs4_bec.loc[0, 'HS4']
for i in range(len(hs4)) :
    hs4Temp = hs4.loc[i, 'HS4']
    for j in range(3512):
        hsbecTemp = hs4_bec.loc[j, 'HS4']
        if hs4Temp == hsbecTemp and hs4_bec.loc[j, 'BEC'] not in hs4_dict[hs4Temp]:
            hs4_dict[hs4Temp].append(hs4_bec.loc[j, 'BEC'])
        pass

# %%
# korea exported 파일 불러오기
korea_exported_list = pd.read_table('C:\project2\Trade_map_List_of_products_exported_and_imported\Trade_Map_-_List_of_products_exported_by_Korea__Republic_of.txt', sep = '\t')

# code -> hs로 컬럼 이름 변경
korea_exported_list.rename(columns={'Code':'HS'}, inplace=True)
korea_exported_list.head()
# Out:
#        HS                                      Product label  \
# 0   TOTAL                                       All products
# 1  854232         Electronic integrated circuits as memories
# 2  854231  Electronic integrated circuits as processors a...
# 3  271019  Medium oils and preparations, of petroleum or ...
# 4  870323  Motor cars and other motor vehicles principall...
#
#    Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0               547854448               559648708               573091134
# 1                16611973                21964136                28849532
# 2                21228826                20702672                18514980
# 3                43536414                39290957                37799193
# 4                27767857                27237499                27337065
#
#    Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# 0               526900733               495465606               573716618
# 1                28856912                31612095                60506974
# 2                19887934                17066083                21362697
# 3                22784332                18938588                25256941
# 4                24060624                22007933                19133730
#
#    Exported value in 2018  Exported value in 2019  Exported value in 2020  \
# 0               605169190               542333337               512788606
# 1                83048246                53163163                52359154
# 2                22100868                20681846                23516687
# 3                34171305                29751793                17844010
# 4                19612091                19701460                15352522
#
#    Exported value in 2021  Unnamed: 12
# 0               644438622          NaN
# 1                69177215          NaN
# 2                30406085          NaN
# 3                26178125          NaN
# 4                16416185          NaN

# %%
#   1) code 열에 total -> 0으로 변경
korea_exported_list.loc[0, 'HS'] = 000000

#   2) korea 데이터 프레임에 hs 코드 데이터 타입 형변환
# korea_exported_list['HS'] = pd.to_numeric(korea_exported_list['HS'])

#   2) merge를 사용해 hs코드 기준으로 데이터 프레임 병합
korea_exported_list = pd.merge(korea_exported_list, hs_bec, how='left', on='HS')

#   2-2 hs코드 잘라서 hs4에 넣어주기
korea_exported_list['HS'] = korea_exported_list['HS'].astype('str')
korea_exported_list['HS4'] = korea_exported_list['HS'].str.slice(0, 4)

#   3) 병합된 데이터 프레임에 결측값 확인
korea_exported_list.isnull().sum()

no_exported_id = korea_exported_list[(korea_exported_list['Exported value in 2012'] == 0)
                    & (korea_exported_list['Exported value in 2013'] == 0)
                    & (korea_exported_list['Exported value in 2014'] == 0)
                    & (korea_exported_list['Exported value in 2015'] == 0)
                    & (korea_exported_list['Exported value in 2016'] == 0)
                    & (korea_exported_list['Exported value in 2017'] == 0)
                    & (korea_exported_list['Exported value in 2018'] == 0)
                    & (korea_exported_list['Exported value in 2019'] == 0)
                    & (korea_exported_list['Exported value in 2020'] == 0)
                    & (korea_exported_list['Exported value in 2021'] == 0)].index

# 거래품목 없는 인덱스 제거
korea_exported_list = korea_exported_list.drop(no_exported_id)
korea_exported_list.isnull().sum()
# Out:
# HS                           0
# Product label                0
# Exported value in 2012       0
# Exported value in 2013       0
# Exported value in 2014       0
# Exported value in 2015       0
# Exported value in 2016       0
# Exported value in 2017       0
# Exported value in 2018       0
# Exported value in 2019       0
# Exported value in 2020       0
# Exported value in 2021       0
# Unnamed: 12               5195
# HS4                          0
# BEC                       5195
# BEC_Pro                   5195
# BEC_Spec                  5195
# dtype: int64

# %%
add_BEC = korea_exported_list[korea_exported_list['BEC'].isnull()]
add_BEC['HS'] = add_BEC['HS'].astype('float')
add_BEC

add_index = add_BEC.index
add_index= list(add_index)

hs4_count = hs4_bec.groupby('HS4').count()
add_BEC.head()

hs4_hs_bec = hs_bec[['HS','BEC']]
add_BEC.drop(['BEC'], axis=1, inplace=True)



add_BEC = pd.merge(add_BEC, hs4_hs_bec, how='left', on='HS')
add_BEC.head()
# add_BEC.isna().count()
# Out:
#          HS                                      Product label  \
# 0       0.0                                       All products
# 1  854232.0         Electronic integrated circuits as memories
# 2  854231.0  Electronic integrated circuits as processors a...
# 3  271019.0  Medium oils and preparations, of petroleum or ...
# 4  870323.0  Motor cars and other motor vehicles principall...
#
#    Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0               547854448               559648708               573091134
# 1                16611973                21964136                28849532
# 2                21228826                20702672                18514980
# 3                43536414                39290957                37799193
# 4                27767857                27237499                27337065
#
#    Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# 0               526900733               495465606               573716618
# 1                28856912                31612095                60506974
# 2                19887934                17066083                21362697
# 3                22784332                18938588                25256941
# 4                24060624                22007933                19133730
#
#    Exported value in 2018  Exported value in 2019  Exported value in 2020  \
# 0               605169190               542333337               512788606
# 1                83048246                53163163                52359154
# 2                22100868                20681846                23516687
# 3                34171305                29751793                17844010
# 4                19612091                19701460                15352522
#
#    Exported value in 2021  Unnamed: 12   HS4 BEC_Pro BEC_Spec       BEC
# 0               644438622          NaN     0     NaN      NaN       NaN
# 1                69177215          NaN  8542     NaN      NaN  611220.0
# 2                30406085          NaN  8542     NaN      NaN  611220.0
# 3                26178125          NaN  2710     NaN      NaN  213101.0
# 4                16416185          NaN  8703     NaN      NaN  513202.0

# %%
add_BEC.isnull().sum()
# Out:
# HS                           0
# Product label                0
# Exported value in 2012       0
# Exported value in 2013       0
# Exported value in 2014       0
# Exported value in 2015       0
# Exported value in 2016       0
# Exported value in 2017       0
# Exported value in 2018       0
# Exported value in 2019       0
# Exported value in 2020       0
# Exported value in 2021       0
# Unnamed: 12               5195
# HS4                          0
# BEC_Pro                   5195
# BEC_Spec                  5195
# BEC                         81
# dtype: int64

# %%
# for i in add_index:
#     for key, value in hs4_dict.items():
#         count = len(hs4_dict[key]) # 몇개의 bec 코드 갖고 있는지
#         keyList = hs4_dict.keys()
#         for item in keyList:
#             # if count > 1 and add_BEC.loc[i, 'HS4'] == item:
#             #     print(item)
#             # pass

# %%
add_BEC.isna().sum()
# Out:
# HS                           0
# Product label                0
# Exported value in 2012       0
# Exported value in 2013       0
# Exported value in 2014       0
# Exported value in 2015       0
# Exported value in 2016       0
# Exported value in 2017       0
# Exported value in 2018       0
# Exported value in 2019       0
# Exported value in 2020       0
# Exported value in 2021       0
# Unnamed: 12               5195
# BEC_Pro                   5195
# BEC_Spec                  5195
# HS4                         79
# BEC                         81
# dtype: int64

# %%
for i in add_index:
    for key, value in hs4_dict.items():
        count = len(hs4_dict[key]) # 몇개의 bec 코드 갖고 있는지
        keyList = hs4_dict.keys()
        print(add_BEC.loc[i,'HS4'])
        # if count > 1 & ((add_BEC.loc[i,'HS4']) == key) :
        #     for j in range(count):
        #         add_df = add_BEC.loc[[i]]
        #         add_BEC = pd.concat([add_BEC, add_df])
        # pass

add_BEC.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\bigdata\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\bigdata\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\bigdata\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\project2\Python\0622_hs4G.ipynb Cell 18' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/project2/Python/0622_hs4G.ipynb#ch0000019?line=3'>4</a>         count = len(hs4_dict[key]) # 몇개의 bec 코드 갖고 있는지
#       <a href='vscode-notebook-cell:/c%3A/project2/Python/0622_hs4G.ipynb#ch0000019?line=4'>5</a>         keyList = hs4_dict.keys()
# ----> <a href='vscode-notebook-cell:/c%3A/project2/Python/0622_hs4G.ipynb#ch0000019?line=5'>6</a>         print(add_BEC.loc[i,'HS4'])
#       <a href='vscode-notebook-cell:/c%3A/project2/Python/0622_hs4G.ipynb#ch0000019?line=6'>7</a>         # if count > 1 & ((add_BEC.loc[i,'HS4']) == key) :
#       <a href='vscode-notebook-cell:/c%3A/project2/Python/0622_hs4G.ipynb#ch0000019?line=7'>8</a>         #     for j in range(count):
#       <a href='vscode-notebook-cell:/c%3A/project2/Python/0622_hs4G.ipynb#ch0000019?line=8'>9</a>         #         add_df = add_BEC.loc[[i]]
#      <a href='vscode-notebook-cell:/c%3A/project2/Python/0622_hs4G.ipynb#ch0000019?line=9'>10</a>         #         add_BEC = pd.concat([add_BEC, add_df])
#      <a href='vscode-notebook-cell:/c%3A/project2/Python/0622_hs4G.ipynb#ch0000019?line=10'>11</a>         # pass
#      <a href='vscode-notebook-cell:/c%3A/project2/Python/0622_hs4G.ipynb#ch0000019?line=12'>13</a> add_BEC.head()
#
# File c:\bigdata\lib\site-packages\pandas\core\indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File c:\bigdata\lib\site-packages\pandas\core\frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
#    3619     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3620     #  results if our categories are integers that dont match our codes
#    3621     # IntervalIndex: IntervalTree has no get_loc
# -> 3622     row = self.index.get_loc(index)
#    3623     return series._values[row]
#    3625 # For MultiIndex going through engine effectively restricts us to
#    3626 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File c:\bigdata\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 0

# %%
# for i in add_index:
#     for key, value in hs4_dict.items():
#         count = len(hs4_dict[key]) # 몇개의 bec 코드 갖고 있는지
#         keyList = hs4_dict.keys()
#         for item in keyList:
#             if bool(count > 1) & bool(add_BEC.loc[i, 'HS4'] == item) :
#                 print( "count={0} item={1}".format(count, item))
#                 for j in range(count):
#                    add_df = add_BEC.loc[[i]]
#                    add_BEC = pd.concat([add_BEC, add_df])
#             pass

# add_BEC.head()

# %%
# for i in range(len(add_BEC)):
#     for key, value in hs4_dict.items():
#         count = len(hs4_dict[key])
#         keyList = hs4_dict.keys()
#         if (count > 1) and (add_BEC.loc[i, 'HS4']) == key :
#             add_df = add_BEC.loc[[i]]
#             add_BEC = pd.concat([add_BEC, add_df])
