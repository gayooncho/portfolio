# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# 사우디 수출 물품 리스트 불러오기
saudi_exported_list = pd.read_table('C:\project2\Trade_map_List_of_products_exported_and_imported\Trade_Map_-_List_of_products_exported_by_Saudi_Arabia.txt', sep = '\t')
saudi_exported_list.rename(columns={'Code':'HS'}, inplace=True)
saudi_exported_list.head()
# Out:
#        HS                                      Product label  \
# 0   TOTAL                                       All products
# 1  999999                Commodities not elsewhere specified
# 2  390210                    Polypropylene, in primary forms
# 3  390110  Polyethylene with a specific gravity of < 0,94...
# 4  390120  Polyethylene with a specific gravity of >= 0,9...
#
#    Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0               387373983               375360918               341947183
# 1                   58175                   53598                   44142
# 2                 5030023                 5627839                 6310098
# 3                 3285565                 4016457                 4133526
# 4                 4878602                 5111909                 6007595
#
#    Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# 0               213376375               178874135               220068596
# ...

# %%
# hs, bec 파일 불러오기
hs17_bec5 = pd.read_csv('C:\project2\BEC5Correlations\HS17BEC5.csv')

# hs, bec 코드 불러오기
# hs code, 이름, bec 코드 추출
hs_bec = hs17_bec5[['HS6', 'BEC5Code1']]

# hs code -> code 이름변경
hs_bec.rename(columns={'HS6':'HS', 'BEC5Code1':'BEC'}, inplace=True)
hs_bec.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8492\4220385039.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs_bec.rename(columns={'HS6':'HS', 'BEC5Code1':'BEC'}, inplace=True)
#       HS       BEC
# 0  10121  712010.0
# 1  10129    1111.0
# 2  10130    1111.0
# 3  10190    1111.0
# 4  10221  112010.0

# %%
# 데이터 합치기
# code에 total 000000 으로 바꿔주기
saudi_exported_list.loc[0, 'HS'] = 000000

saudi_exported_list['HS'] = pd.to_numeric(saudi_exported_list['HS'])

# korea_list.info()

# hs_bec.dtypes

saudi_exported_list = pd.merge(saudi_exported_list, hs_bec, how='left', on='HS')
saudi_exported_list.head()
# Out:
#        HS                                      Product label  \
# 0       0                                       All products
# 1  999999                Commodities not elsewhere specified
# 2  390210                    Polypropylene, in primary forms
# 3  390110  Polyethylene with a specific gravity of < 0,94...
# 4  390120  Polyethylene with a specific gravity of >= 0,9...
#
#    Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0               387373983               375360918               341947183
# 1                   58175                   53598                   44142
# 2                 5030023                 5627839                 6310098
# 3                 3285565                 4016457                 4133526
# 4                 4878602                 5111909                 6007595
#
#    Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# 0               213376375               178874135               220068596
# ...

# %%
# 파일 내보내기
saudi_exported_list.to_csv('./saudi_exported_list.csv')
