# %%
import numpy as np
import pandas as pd

# %%
# hs / bec 파일 불러오기, excel 파일의 두번째 sheet
hs_bec = pd.read_excel('C:\project2\BEC5Correlations\HS2012-17-BEC5 -- 08 Nov 2018.xlsx'
                       , sheet_name = "HS17BEC5")

# hs4, hs6, bec, bec processing, bec specitication 목록만 별도로 추출
hs_bec = hs_bec[['HS4','HS6','BEC5Code1', 'BEC5Processing', 'BEC5Specification']]

# hs code -> code 이름변경
hs_bec.rename(columns={'HS4':'HS4', 'HS6':'HS', 'BEC5Code1':'BEC', }, inplace=True)

# %%
hs4_bec = hs_bec[['HS4','BEC']]

# hs4, bec코드 정리
hs4_bec['HS4'] = hs4_bec['HS4'].astype('int')


hs4_bec.dropna(axis=0, inplace= True)
# hs4_count = hs4_bec['HS4'].value_counts()
# hs4_count = pd.DataFrame(hs4_count)

# hs4_count.reset_index(inplace=True)
# hs4_count.columns = ['HS4', 'HS4_COUNT']
# hs4_bec.groupby('HS4').count()

hs4_bec['HS4'] = hs4_bec['HS4'].astype('int')
hs4_bec['BEC'] = hs4_bec['BEC'].astype('float')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20748\1669214109.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec['HS4'] = hs4_bec['HS4'].astype('int')
# C:\Users\user\AppData\Local\Temp\ipykernel_20748\1669214109.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec.dropna(axis=0, inplace= True)
# C:\Users\user\AppData\Local\Temp\ipykernel_20748\1669214109.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec['HS4'] = hs4_bec['HS4'].astype('int')
# C:\Users\user\AppData\Local\Temp\ipykernel_20748\1669214109.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec['BEC'] = hs4_bec['BEC'].astype('float')

# %%
hs4 = hs4_bec['HS4']

hs4.drop_duplicates(inplace=True)

hs4 = hs4.to_frame()

hs4.reset_index(inplace=True)
hs4.count()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20748\909227547.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4.drop_duplicates(inplace=True)
# index    1222
# HS4      1222
# dtype: int64

# %%
# hs4에 대하여 bec 코드가 없는 행
# bec 값에 0

hs4_bec.loc[3513,'HS4'] = 0
hs4_bec.loc[3542,'HS4'] = 0
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20748\1599587323.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs4_bec.loc[3513,'HS4'] = 0

# %%
#hs4와 bec 사전 만들기

# from collections import defaultdict
# hs4_dict = defaultdict(list)
    
# hs4_bec.loc[0, 'HS4']
# for i in range(len(hs4)) :  # hs4코드만 있는 데이터 프레임 #1222개
#     hs4Temp = hs4.loc[i, 'HS4']
#     for j in range(len(hs4_bec)):   #hs4와 bec 코드가 함께 있음 # 5387개
#         hsbecTemp = hs4_bec.loc[j, 'HS4']
#         if hs4Temp == hsbecTemp and hs4_bec.loc[j, 'BEC'] not in hs4_dict[hs4Temp]:
#             hs4_dict[hs4Temp].append(hs4_bec.loc[j, 'BEC'])
#         pass

# %%
from collections import defaultdict
hs4_dict = defaultdict(list)

hs4_bec.reset_index(inplace=True)

for j in range(len(hs4_bec)):
    hsbecTemp = hs4_bec.loc[j, 'HS4']
    for i in range(len(hs4)):
        hs4Temp = hs4.loc[i, 'HS4']
        if hs4Temp == hsbecTemp and hs4_bec.loc[j, 'BEC'] not in hs4_dict[hs4Temp]:
            hs4_dict[hs4Temp].append(hs4_bec.loc[j, 'BEC'])

# %%
# india exported 파일 불러오기
india_exported_list = pd.read_table('C:\project2\Trade_map_List_of_products_exported_and_imported\Trade_Map_-_List_of_products_exported_by_India.txt', sep = '\t')

# code -> hs로 컬럼 이름 변경
india_exported_list.rename(columns={'Code':'HS'}, inplace=True)
india_exported_list.head()
# Out:
#        HS                                      Product label  \
# 0   TOTAL                                       All products
# 1  271019  Medium oils and preparations, of petroleum or ...
# 2  710239  Diamonds, worked, but not mounted or set (excl...
# 3  271012  Light oils and preparations, of petroleum or b...
# 4  300490  Medicaments consisting of mixed or unmixed pro...
#
#    Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0               289564769               336611389               317544642
# 1                30189091                46921811                40682152
# 2                20819464                27084559                22475223
# 3                       0                19765201                19742787
# 4                 6631679                 8375464                 8288881
#
#    Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# 0               263889005               260963959               295862157
# 1                17629287                16081655                22227429
# 2                20556917                22437928                22882992
# 3                11962340                10664422                12477483
# 4                 9327226                 9796992                 9658816
#
#    Exported value in 2018  Exported value in 2019  Exported value in 2020  \
# 0               323997680               323250726               275488745
# 1                32327270                29790424                17626804
# 2                24254392                20575455                14655837
# 3                14810618                12646438                 8453439
# 4                10782950                12390505                14059367
#
#    Exported value in 2021  Unnamed: 12
# 0               394813673          NaN
# 1                34867787          NaN
# 2                23844452          NaN
# 3                19167099          NaN
# 4                14718722          NaN

# %%
#   1) code 열에 total -> 0으로 변경
# korea_exported_list.loc[0, 'HS'] = 000000
# 제거
india_exported_list = india_exported_list.drop([india_exported_list.index[0]])

#   2) japan 데이터 프레임에 hs 코드 데이터 타입 형변환
india_exported_list['HS'] = pd.to_numeric(india_exported_list['HS'])

#   2) merge를 사용해 hs코드 기준으로 데이터 프레임 병합
india_exported_list = pd.merge(india_exported_list, hs_bec, how='left', on='HS')

#   2-1) hs 코드 자리수 맞춰주기 -> 5자리인경우 앞에 0붙여주기
india_exported_list['HS'] = india_exported_list['HS'].astype('str')
#       HS코드 6자리로 맞춰주기, 없는경우 left에 0으로 붙여줌
# india_exported_list['HS'].str.pad(width=6, side='left', fillchar='0')
india_exported_list['HS'] = india_exported_list['HS'].str.zfill(width=6)

#   2-2 hs코드 잘라서 hs4에 넣어주기
india_exported_list['HS4'] = india_exported_list['HS'].str.slice(0, 4)


india_exported_list.head()
# Out:
#        HS                                      Product label  \
# 0  271019  Medium oils and preparations, of petroleum or ...
# 1  710239  Diamonds, worked, but not mounted or set (excl...
# 2  271012  Light oils and preparations, of petroleum or b...
# 3  300490  Medicaments consisting of mixed or unmixed pro...
# 4  711319  Articles of jewellery and parts thereof, of pr...
#
#    Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0                30189091                46921811                40682152
# 1                20819464                27084559                22475223
# 2                       0                19765201                19742787
# 3                 6631679                 8375464                 8288881
# 4                17276723                 9572682                11222490
#
#    Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# 0                17629287                16081655                22227429
# 1                20556917                22437928                22882992
# 2                11962340                10664422                12477483
# 3                 9327226                 9796992                 9658816
# 4                 7388131                 9204800                 8371671
#
#    Exported value in 2018  Exported value in 2019  Exported value in 2020  \
# 0                32327270                29790424                17626804
# 1                24254392                20575455                14655837
# 2                14810618                12646438                 8453439
# 3                10782950                12390505                14059367
# 4                11609406                12366518                 5678174
#
#    Exported value in 2021  Unnamed: 12   HS4       BEC BEC5Processing  \
# 0                34867787          NaN  2710  213101.0        PRIMARY
# 1                23844452          NaN  7102  411210.0      PROCESSED
# 2                19167099          NaN  2710  213101.0        PRIMARY
# 3                14718722          NaN  3004  711220.0      PROCESSED
# 4                 8430817          NaN  7113  413202.0      PROCESSED
#
#   BEC5Specification
# 0               NaN
# 1           GENERIC
# 2               NaN
# 3          SPECIFIC
# 4               NaN

# %%
no_exported_id = india_exported_list[(india_exported_list['Exported value in 2017'] == 0)
                    & (india_exported_list['Exported value in 2018'] == 0)
                    & (india_exported_list['Exported value in 2019'] == 0)
                    & (india_exported_list['Exported value in 2020'] == 0)
                    & (india_exported_list['Exported value in 2021'] == 0)].index

# 거래품목 없는 인덱스 제거
india_exported_list = india_exported_list.drop(no_exported_id)
india_exported_list.isnull().sum()
# Out:
# HS                           0
# Product label                0
# Exported value in 2012       0
# Exported value in 2013       0
# Exported value in 2014       0
# Exported value in 2015       0
# Exported value in 2016       0
# Exported value in 2017       0
# Exported value in 2018       0
# Exported value in 2019       0
# Exported value in 2020       0
# Exported value in 2021       0
# Unnamed: 12               5239
# HS4                          0
# BEC                         66
# BEC5Processing             762
# BEC5Specification         1713
# dtype: int64

# %%
add_BEC = india_exported_list[india_exported_list['BEC'].isnull()]
# NaN값을 채워지기 위해 hs타입 형변환??
# add_BEC['HS'] = add_BEC['HS'].astype('float')
add_BEC

# 행을 늘려주기 위한 변수
hs4_count = hs4_bec.groupby('HS4').count()

# BEC 코드를 새로 부여하기 위해 기존 BEC 행 제거
add_BEC.drop(['BEC'], axis=1, inplace=True)

add_BEC.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20748\3427973275.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_BEC.drop(['BEC'], axis=1, inplace=True)
#           HS                                      Product label  \
# 603   999999                Commodities not elsewhere specified
# 4992  291470  Halogenated, sulphonated, nitrated or nitrosat...
# 5007  300210  Antisera and other blood fractions and immunol...
# 5008  300440  Medicaments containing alkaloids or derivative...
# 5028  441232  Plywood consisting solely of sheets of wood <=...
#
#       Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 603                  2527225                 5013624                  959798
# 4992                   64724                   77189                   79706
# 5007                   40082                   57442                   47849
# 5008                   79025                   44566                   41632
# 5028                     944                     193                    1239
#
#       Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# 603                  2293003                  820957                  277469
# 4992                   86934                   74487                    9610
# 5007                   45064                   86696                   17211
# 5008                   49552                   45286                    2503
# 5028                    1140                     602                       7
#
#       Exported value in 2018  Exported value in 2019  Exported value in 2020  \
# 603                   178658                  212037                   99582
# 4992                       0                       0                       0
# 5007                       0                       0                       0
# 5008                       0                       0                       0
# 5028                       0                       0                       0
#
#       Exported value in 2021  Unnamed: 12   HS4 BEC5Processing  \
# 603                    88618          NaN  9999            NaN
# 4992                       0          NaN  2914            NaN
# 5007                       0          NaN  3002            NaN
# 5008                       0          NaN  3004            NaN
# 5028                       0          NaN  4412            NaN
#
#      BEC5Specification
# 603                NaN
# 4992               NaN
# 5007               NaN
# 5008               NaN
# 5028               NaN

# %%
## hs4 와 bec 개수 
hs4_bec_count = hs4_bec
# hs4와 bec 겹치는 행제거
hs4_bec_count.drop_duplicates(inplace=True)

# hs4별 bec 개수 데이터 프레임 : hs4_count 
hs4_count = hs4_bec_count.groupby('HS4').count()

# 열제거
hs4_count = hs4_count.drop([hs4_count.columns[0]], axis=1)

# %%
hs4_count
# Out:
#         BEC
# HS4
# 0.0       0
# 101.0     4
# 102.0     5
# 103.0     3
# 104.0     2
# ...     ...
# 9702.0    1
# 9703.0    1
# 9704.0    1
# 9705.0    1
# 9706.0    1
#
# [1223 rows x 1 columns]

# %%
hs4_count.loc[101]
# Out:
# BEC    4
# Name: 101.0, dtype: int64

# %%
add_BEC_index = (add_BEC.index).to_list()
hs4_count_index = (hs4_count.index).to_list()

### 행 늘리기 - how
# 1. 늘려야하는 행들 확인
# 2. n개로 행 늘려주기
for i in add_BEC_index:
    com_key = int(add_BEC.loc[i, 'HS4'])
    for j in hs4_count_index:
        count = int(hs4_count.loc[j])       # count개수만큼 행 추가
        hs4Temp = int(j)
        # print(hs4Temp)
        # print(count, hs4Temp, com_key)
        if (count > 1) & (com_key == hs4Temp):  # 추가해야할 행이 2개이상이고, com_key와 hs4Tmep이 같을 경우
            for m in range(count):  # count 개수만큼 행 추가
                # add_BEC = pd.concat([add_BEC, add_BEC.loc[[i]]], ignore_index = True)
                # add_BEC = pd.concat([add_BEC, add_BEC.loc[[i]]], ignore_index = True)
                add_BEC = pd.concat([add_BEC, add_BEC.loc[[i]]], ignore_index = True)

# %%
add_BEC
# Out:
#          HS                                      Product label  \
# 0    999999                Commodities not elsewhere specified
# 1    291470  Halogenated, sulphonated, nitrated or nitrosat...
# 2    300210  Antisera and other blood fractions and immunol...
# 3    300440  Medicaments containing alkaloids or derivative...
# 4    441232  Plywood consisting solely of sheets of wood <=...
# ..      ...                                                ...
# 740  291470  Halogenated, sulphonated, nitrated or nitrosat...
# 741  291470  Halogenated, sulphonated, nitrated or nitrosat...
# 742  291470  Halogenated, sulphonated, nitrated or nitrosat...
# 743  291470  Halogenated, sulphonated, nitrated or nitrosat...
# 744  291470  Halogenated, sulphonated, nitrated or nitrosat...
#
#      Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0                   2527225                 5013624                  959798
# 1                     64724                   77189                   79706
# 2                     40082                   57442                   47849
# 3                     79025                   44566                   41632
# 4                       944                     193                    1239
# ..                      ...                     ...                     ...
# 740                   64724                   77189                   79706
# 741                   64724                   77189                   79706
# 742                   64724                   77189                   79706
# 743                   64724                   77189                   79706
# 744                   64724                   77189                   79706
#
#      Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# 0                   2293003                  820957                  277469
# 1                     86934                   74487                    9610
# 2                     45064                   86696                   17211
# 3                     49552                   45286                    2503
# 4                      1140                     602                       7
# ..                      ...                     ...                     ...
# 740                   86934                   74487                    9610
# 741                   86934                   74487                    9610
# 742                   86934                   74487                    9610
# 743                   86934                   74487                    9610
# 744                   86934                   74487                    9610
#
#      Exported value in 2018  Exported value in 2019  Exported value in 2020  \
# 0                    178658                  212037                   99582
# 1                         0                       0                       0
# 2                         0                       0                       0
# 3                         0                       0                       0
# 4                         0                       0                       0
# ..                      ...                     ...                     ...
# 740                       0                       0                       0
# 741                       0                       0                       0
# 742                       0                       0                       0
# 743                       0                       0                       0
# 744                       0                       0                       0
#
#      Exported value in 2021  Unnamed: 12   HS4 BEC5Processing  \
# 0                     88618          NaN  9999            NaN
# 1                         0          NaN  2914            NaN
# 2                         0          NaN  3002            NaN
# 3                         0          NaN  3004            NaN
# 4                         0          NaN  4412            NaN
# ..                      ...          ...   ...            ...
# 740                       0          NaN  2914            NaN
# 741                       0          NaN  2914            NaN
# 742                       0          NaN  2914            NaN
# 743                       0          NaN  2914            NaN
# 744                       0          NaN  2914            NaN
#
#     BEC5Specification
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 740               NaN
# 741               NaN
# 742               NaN
# 743               NaN
# 744               NaN
#
# [745 rows x 16 columns]

# %%
# 금액 나누기
for i in range(len(add_BEC)):
    com_key = int(add_BEC.loc[i, 'HS4'])
    for j in hs4_count_index:
        count = int(hs4_count.loc[j])       # count개수만큼 행 추가
        hs4Temp = int(j)
        if (count > 1) & (com_key == hs4Temp):
            for m in range(count):      # count 개수만큼 금액 나누기            
                add_BEC.loc[i,'Exported value in 2012'] = (add_BEC.loc[i, 'Exported value in 2012'] / count)
                add_BEC.loc[i,'Exported value in 2013'] = (add_BEC.loc[i, 'Exported value in 2013'] / count)
                add_BEC.loc[i,'Exported value in 2014'] = (add_BEC.loc[i, 'Exported value in 2014'] / count)
                add_BEC.loc[i,'Exported value in 2015'] = (add_BEC.loc[i, 'Exported value in 2015'] / count)
                add_BEC.loc[i,'Exported value in 2016'] = (add_BEC.loc[i, 'Exported value in 2016'] / count)
                add_BEC.loc[i,'Exported value in 2017'] = (add_BEC.loc[i, 'Exported value in 2017'] / count)
                add_BEC.loc[i,'Exported value in 2018'] = (add_BEC.loc[i, 'Exported value in 2018'] / count)
                add_BEC.loc[i,'Exported value in 2019'] = (add_BEC.loc[i, 'Exported value in 2019'] / count)
                add_BEC.loc[i,'Exported value in 2020'] = (add_BEC.loc[i, 'Exported value in 2020'] / count)
                add_BEC.loc[i,'Exported value in 2021'] = (add_BEC.loc[i, 'Exported value in 2021'] / count)

# %%
add_BEC
# Out:
#          HS                                      Product label  \
# 0    999999                Commodities not elsewhere specified
# 1    291470  Halogenated, sulphonated, nitrated or nitrosat...
# 2    300210  Antisera and other blood fractions and immunol...
# 3    300440  Medicaments containing alkaloids or derivative...
# 4    441232  Plywood consisting solely of sheets of wood <=...
# ..      ...                                                ...
# 740  291470  Halogenated, sulphonated, nitrated or nitrosat...
# 741  291470  Halogenated, sulphonated, nitrated or nitrosat...
# 742  291470  Halogenated, sulphonated, nitrated or nitrosat...
# 743  291470  Halogenated, sulphonated, nitrated or nitrosat...
# 744  291470  Halogenated, sulphonated, nitrated or nitrosat...
#
#      Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0              2.527225e+06            5.013624e+06            9.597980e+05
# 1              3.508695e-15            4.184424e-15            4.320871e-15
# 2              1.034586e-04            1.482678e-04            1.235066e-04
# 3              8.863180e-09            4.998373e-09            4.669306e-09
# 4              1.146267e-03            2.343533e-04            1.504475e-03
# ..                      ...                     ...                     ...
# 740            3.508695e-15            4.184424e-15            4.320871e-15
# 741            3.508695e-15            4.184424e-15            4.320871e-15
# 742            3.508695e-15            4.184424e-15            4.320871e-15
# 743            3.508695e-15            4.184424e-15            4.320871e-15
# 744            3.508695e-15            4.184424e-15            4.320871e-15
#
#      Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# 0              2.293003e+06            8.209570e+05            2.774690e+05
# 1              4.712702e-15            4.037948e-15            5.209591e-16
# 2              1.163181e-04            2.237775e-04            4.442460e-05
# 3              5.557587e-09            5.079126e-09            2.807281e-10
# 4              1.384263e-03            7.309879e-04            8.499860e-06
# ..                      ...                     ...                     ...
# 740            4.712702e-15            4.037948e-15            5.209591e-16
# 741            4.712702e-15            4.037948e-15            5.209591e-16
# 742            4.712702e-15            4.037948e-15            5.209591e-16
# 743            4.712702e-15            4.037948e-15            5.209591e-16
# 744            4.712702e-15            4.037948e-15            5.209591e-16
#
#      Exported value in 2018  Exported value in 2019  Exported value in 2020  \
# 0                    178658                  212037                   99582
# 1                         0                       0                       0
# 2                         0                       0                       0
# 3                         0                       0                       0
# 4                         0                       0                       0
# ..                      ...                     ...                     ...
# 740                       0                       0                       0
# 741                       0                       0                       0
# 742                       0                       0                       0
# 743                       0                       0                       0
# 744                       0                       0                       0
#
#      Exported value in 2021  Unnamed: 12   HS4 BEC5Processing  \
# 0                     88618          NaN  9999            NaN
# 1                         0          NaN  2914            NaN
# 2                         0          NaN  3002            NaN
# 3                         0          NaN  3004            NaN
# 4                         0          NaN  4412            NaN
# ..                      ...          ...   ...            ...
# 740                       0          NaN  2914            NaN
# 741                       0          NaN  2914            NaN
# 742                       0          NaN  2914            NaN
# 743                       0          NaN  2914            NaN
# 744                       0          NaN  2914            NaN
#
#     BEC5Specification
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 740               NaN
# 741               NaN
# 742               NaN
# 743               NaN
# 744               NaN
#
# [745 rows x 16 columns]

# %%
add_BEC.isnull().sum()
# Out:
# HS                          0
# Product label               0
# Exported value in 2012      0
# Exported value in 2013      0
# Exported value in 2014      0
# Exported value in 2015      0
# Exported value in 2016      0
# Exported value in 2017      0
# Exported value in 2018      0
# Exported value in 2019      0
# Exported value in 2020      0
# Exported value in 2021      0
# Unnamed: 12               745
# HS4                         0
# BEC5Processing            745
# BEC5Specification         745
# dtype: int64

# %%
# ### 원 데이터에 bec 코드 넣어주기
# for i in range(len(add_BEC)):
#     hs4_temp = int(add_BEC.loc[i, 'HS4'])
#     for key, value in hs4_dict.items():
#         if hs4_temp == key:
#             for j in value:
#                 # print(type(j))
#                 add_BEC.loc[i, 'BEC'] = j

# %%
for key, value in hs4_dict.items():
    for i in range(len(add_BEC)):
        hs4_temp = int(add_BEC.loc[i, 'HS4'])
        if hs4_temp == key:
            for j in value:
                add_BEC.loc[i, 'BEC'] = j

# %%
hs4_dict[101]
# Out:
# [712010.0, 1111.0]

# %%
add_BEC.isnull().sum()
# Out:
# HS                          0
# Product label               0
# Exported value in 2012      0
# Exported value in 2013      0
# Exported value in 2014      0
# Exported value in 2015      0
# Exported value in 2016      0
# Exported value in 2017      0
# Exported value in 2018      0
# Exported value in 2019      0
# Exported value in 2020      0
# Exported value in 2021      0
# Unnamed: 12               745
# HS4                         0
# BEC5Processing            745
# BEC5Specification         745
# BEC                         5
# dtype: int64

# %%
india_exported_list.reset_index(drop=True, inplace = True)

for i in range(len(add_BEC)):
    hsTemp = add_BEC.loc[i,'HS']
    becTemp = add_BEC.loc[i,'BEC']
    # 기존 데이터 프레임 hs 값과 add hs값이 같을때
    for j in range(len(india_exported_list)) :
        if hsTemp == india_exported_list.loc[j, 'HS'] :
            india_exported_list.loc[j,'BEC'] = becTemp
            # print(india_exported_list.loc[j, 'BEC'])
            # else :
            #     print(j)

# korea_exported_list.drop_duplicates(inplace=True)
india_exported_list.isnull().sum()
# Out:
# HS                           0
# Product label                0
# Exported value in 2012       0
# Exported value in 2013       0
# Exported value in 2014       0
# Exported value in 2015       0
# Exported value in 2016       0
# Exported value in 2017       0
# Exported value in 2018       0
# Exported value in 2019       0
# Exported value in 2020       0
# Exported value in 2021       0
# Unnamed: 12               5239
# HS4                          0
# BEC                          5
# BEC5Processing             762
# BEC5Specification         1713
# dtype: int64

# %%
india_exported_list[india_exported_list['BEC'].isnull()]
# Out:
#           HS                                      Product label  \
# 603   999999                Commodities not elsewhere specified
# 5067  284800  Phosphides, whether or not chemically defined ...
# 5122  690810  Glazed ceramic tiles, mosaic cubes and similar...
# 5127  846900  Typewriters and word-processing machines (excl...
# 5130  690890  Glazed ceramic flags and paving, hearth or wal...
#
#       Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 603                  2527225                 5013624                  959798
# 5067                    1000                     758                     830
# 5122                   10208                   18930                   21402
# 5127                     826                    1454                     551
# 5130                   86044                  171452                  326352
#
#       Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# 603                  2293003                  820957                  277469
# 5067                    1312                    1458                     117
# 5122                   15158                    4205                   51024
# 5127                     775                     978                     235
# 5130                  392319                  475198                   77004
#
#       Exported value in 2018  Exported value in 2019  Exported value in 2020  \
# 603                   178658                  212037                   99582
# 5067                       0                       0                       0
# 5122                       0                       0                       0
# 5127                       0                       0                       0
# 5130                       0                       0                       0
#
#       Exported value in 2021  Unnamed: 12   HS4  BEC BEC5Processing  \
# 603                    88618          NaN  9999  NaN            NaN
# 5067                       0          NaN  2848  NaN            NaN
# 5122                       0          NaN  6908  NaN            NaN
# 5127                       0          NaN  8469  NaN            NaN
# 5130                       0          NaN  6908  NaN            NaN
#
#      BEC5Specification
# 603                NaN
# 5067               NaN
# 5122               NaN
# 5127               NaN
# 5130               NaN
