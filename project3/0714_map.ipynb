# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.rcParams["font.family"] = 'NanumGothic' # 한글폰트
plt.rcParams["figure.figsize"] = (20, 10)

# %%
tree_shp = "C:\project22\python\변수\나무나이_강원도.shp"
tree_prj = "C:\project22\python\변수\나무나이_강원도.prj"
tree_dbf = "C:\project22\python\변수\나무나이_강원도.dbf"
tree_shx = "C:\project22\python\변수\나무나이_강원도.shx"

tree = gpd.read_file(tree_dbf)


region_shp = 'C:\project22\python\변수\SIG_20220324\sig.shp'

region = gpd.read_file('C:\project22\python\변수\SIG_20220324\sig.shp', encoding = 'euc-kr')

# %%
region_id = pd.read_excel('C:\project22\e0f63039b4094befba8d639fdaefa622.xls')
region_id.columns = ['0','1', 'si', 'SIG_CD', 'gu', '5', '6', '7', '8', '9']

# %%
region_id.head(1)
# Out:
#     0    1   si SIG_CD   gu    5    6    7    8    9
# 0 NaN  NaN  NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
region_id= region_id.dropna(thresh = 5)

# %%
region_id = region_id[['si', 'SIG_CD', 'gu', '5', '6', '7']]

# %%
region_id.set_index(keys = 'SIG_CD')
region.set_index(keys = 'SIG_CD')
# Out:
#           SIG_ENG_NM SIG_KOR_NM  \
# SIG_CD
# 11110      Jongno-gu        종로구
# 11140        Jung-gu         중구
# 11170     Yongsan-gu        용산구
# 11200   Seongdong-gu        성동구
# 11215    Gwangjin-gu        광진구
# ...              ...        ...
# 48870    Hamyang-gun        함양군
# 48880   Geochang-gun        거창군
# 48890   Hapcheon-gun        합천군
# 50110        Jeju-si        제주시
# 50130    Seogwipo-si       서귀포시
#
#                                                  geometry
# SIG_CD
# 11110   POLYGON ((956615.453 1953567.199, 956621.579 1...
# 11140   POLYGON ((957890.386 1952616.746, 957909.908 1...
# 11170   POLYGON ((953115.761 1950834.084, 953114.206 1...
# 11200   POLYGON ((959681.109 1952649.605, 959842.412 1...
# 11215   POLYGON ((964825.058 1952633.250, 964875.565 1...
# ...                                                   ...
# 48870   POLYGON ((1017715.723 1751280.191, 1017761.619...
# 48880   POLYGON ((1034571.593 1767759.812, 1034559.208...
# ...

# %%
region_merge = pd.merge(region, region_id, left_index=True, right_index=True)

# %%
region_merge.head()
# Out:
#   SIG_CD_x     SIG_ENG_NM SIG_KOR_NM  \
# 1    11140        Jung-gu         중구
# 3    11200   Seongdong-gu        성동구
# 4    11215    Gwangjin-gu        광진구
# 5    11230  Dongdaemun-gu       동대문구
# 6    11260    Jungnang-gu        중랑구
#
#                                             geometry     si SIG_CD_y   gu  \
# 1  POLYGON ((957890.386 1952616.746, 957909.908 1...     시도      중분류  시군구
# 3  POLYGON ((959681.109 1952649.605, 959842.412 1...  서울특별시    11010  종로구
# 4  POLYGON ((964825.058 1952633.250, 964875.565 1...  서울특별시    11010  종로구
# 5  POLYGON ((962141.919 1956519.461, 962149.853 1...  서울특별시    11010  종로구
# 6  POLYGON ((965698.531 1957987.355, 965772.290 1...  서울특별시    11010  종로구
#
#          5    6               7
# 1      소분류  읍면동           영문 표기
# 3      NaN  NaN       Jongno-gu
# 4  1101053  사직동      Sajik-dong
# 5  1101054  삼청동  Samcheong-dong
# 6  1101055  부암동       Buam-dong

# %%
tree
# Out:
#       STORUNST FROR_CD FRTP_CD KOFTR_GROU DMCLS_CD AGCLS_CD DNST_CD  \
# 0            1       1       1         11        0        1       A
# 1            1       1       1         11        0        1       A
# 2            1       1       1         11        0        1       A
# 3            1       1       2         30        0        1       A
# 4            1       1       2         30        0        1       A
# ...        ...     ...     ...        ...      ...      ...     ...
# 13062        1       2       2         30        0        1       A
# 13063        1       2       2         30        0        1       A
# 13064        1       2       2         30        0        1       A
# 13065        1       2       2         30        0        1       A
# 13066        1       2       2         30        0        1       A
#
#                                                 geometry
# 0      POLYGON ((1005037.143 1962133.702, 1005040.073...
# ...

# %%
tree.loc[6, "geometry"]

# tree_merge = pd.merge(region_merge, tree)

# %%
region_merge

# %%
tree.to_csv('./tree.csv', encoding = 'euc-kr')

# %%
# tree[['geometry']]

# %%
tree.plot()
plt.show()
